# %%
# makes matplotlib (and pandas) plots show up in the notebook
# %matplotlib inline

# the following two lines make all plots show up in formats that are high-resolution
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'svg')

# actually import the Pandas module
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np

# %%
#Get the csv stuff
data = pd.read_csv("plant_bio_project.csv")
data
# Out:
#     Stem Diameter (mm)  Group  Number  plants per pot      Notes Dead?   \
# 0                  0.60     A       1             1.0        NaN    NaN
# 1                   NaN     B       1             NaN        NaN   Dead
# 2                  0.71     C       1             1.0        NaN    NaN
# 3                  0.59     D       1             1.0        NaN    NaN
# 4                   NaN     E       1             NaN        NaN   Dead
# 5                  1.30     A       2             1.0        NaN    NaN
# 6                  0.50     B       2             1.0        NaN    NaN
# 7                   NaN     C       2             NaN        NaN   Dead
# 8                  1.59     D       2             1.0        NaN    NaN
# 9                   NaN     E       2             NaN        NaN   Dead
# 10                 1.23     A       4             2.0        NaN    NaN
# 11                 1.19     B       4             2.0        NaN    NaN
# 12                 1.73     C       4             3.0        NaN    NaN
# 13                 1.50     D       4             2.0  Two Soots    NaN
# 14                 1.37     E       4             2.0        NaN    NaN
# 15                 2.35     A       6             4.0        NaN    NaN
# 16                 0.94     B       6             2.0   2 shoots    NaN
# 17                 0.87     C       6             5.0        NaN    NaN
# 18                 1.17     D       6             2.0        NaN    NaN
# 19                 1.03     E       6             5.0        NaN    NaN
# 20                 0.43     A       8             4.0        NaN    NaN
# 21                 1.00     C       8             4.0        NaN    NaN
# 22                 0.61     D       8             5.0        NaN    NaN
# 23                 0.34     E       8             5.0        NaN    NaN
#
#     Root Biomass  Shoot Biomass
# 0          0.152          0.595
# 1            NaN            NaN
# 2          0.930          0.503
# 3          1.260          1.260
# 4            NaN            NaN
# 5          0.238          0.570
# 6          0.233          2.747
# 7            NaN            NaN
# 8          0.356          4.227
# 9            NaN            NaN
# 10         0.299          1.333
# 11         0.486          0.221
# 12         0.205          0.583
# 13         0.481          1.107
# 14         0.386          0.399
# 15         0.205          0.840
# 16         1.115          0.708
# 17         0.485          0.707
# 18         0.622          0.692
# 19         1.064          1.024
# 20         0.572          1.133
# 21         1.528          0.525
# 22         1.657          0.595
# 23         0.226          0.691

# %%
plt.tight_layout()

ax =plt.subplot(321)
scatter = ax.scatter(data["Group"], data["Root Biomass"])
plt.title("Group vs Root Biomass")
plt.xlabel("Group Number")

ax2 = plt.subplot(322)
ax2.scatter(data["Number"], data["Root Biomass"])
ax2.set_title("Expected Number vs Root Biomass")
ax2.set_xlabel("Expected Number of Plants")
ax2.set_ylabel("Root Biomass")
# Out:
# Text(0,0.5,'Root Biomass')

# %%
scatter = plt.scatter(data["plants per pot"], data["Root Biomass"])
plt.title("Plants vs Root Biomasss")
plt.xlabel("Actual Number of Plants")
plt.ylabel("Root Biomass")
# Out:
# Text(0,0.5,'Root Biomass')

# %%
scatter = plt.scatter(data["plants per pot"], data["Shoot Biomass"])
plt.title("Plants vs Root Biomasss")
plt.xlabel("Actual Number of Plants")
plt.ylabel("Shoot Biomass")
# Out:
# Text(0,0.5,'Shoot Biomass')

# %%
root_biomass_std = np.std(data["Root Biomass"])
print("Root Biomass Std Deviation: ", root_biomass_std)
shoot_biomass_std = np.std(data["Shoot Biomass"])
print("Shoot Biomass Std Deviation: ", shoot_biomass_std)
mask = data["plants per pot"] == 1
print(data[mask])
# print(data[mask])
root_ls = []
shoot_ls = []
for i in range(5):
    mask = data["plants per pot"] == i
    root_ls.append(np.std(data[mask]["Root Biomass"]))
    shoot_ls.append(np.std(data[mask]["Shoot Biomass"]))
# Out:
# Root Biomass Std Deviation:  0.455351512570234
# Shoot Biomass Std Deviation:  0.8993812873303513
#    Stem Diameter (mm)  Group  Number  plants per pot Notes Dead?   \
# 0                 0.60     A       1             1.0   NaN    NaN
# 2                 0.71     C       1             1.0   NaN    NaN
# 3                 0.59     D       1             1.0   NaN    NaN
# 5                 1.30     A       2             1.0   NaN    NaN
# 6                 0.50     B       2             1.0   NaN    NaN
# 8                 1.59     D       2             1.0   NaN    NaN
#
#    Root Biomass  Shoot Biomass
# 0         0.152          0.595
# 2         0.930          0.503
# 3         1.260          1.260
# 5         0.238          0.570
# 6         0.233          2.747
# 8         0.356          4.227
# [nan, 0.41623567709758963, 0.26515493374419585, 0.0, 0.5576691571970687]
